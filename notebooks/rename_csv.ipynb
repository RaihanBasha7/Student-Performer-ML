# %%
import pandas as pd

# Load CSV
df = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\Student-Performer-ML\data\datastudent_performance.csv")

# Rename columns
df.rename(columns={
    "studytime": "study_hours",
    "G1": "previous_score_1",
    "G2": "previous_score_2",
    "G3": "final_score"
}, inplace=True)

# Save back to same file (PERMANENT CHANGE)
df.to_csv(r"C:\Users\hp\OneDrive\Desktop\Student-Performer-ML\data\datastudent_performance.csv", index=False)

print("Column names permanently changed!")
# Out:
# Column names permanently changed!
